# %% [markdown]
# # Exercise 1: Hello World

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape = [1])])
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0])
ys = np.array([-2.0,1.0,4.0,7.0,10.0,13.0])

# %%
model.fit(xs, ys, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 14.4118
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 11.3673
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.9715
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0860
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 5.6020
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.4339
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5144
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7904
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2203
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7712
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4174
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1386
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[31.006361]]

# %% [markdown]
# # Explaination:

# %% [markdown]
# 1.   Import required libraries, and the framework for defining a neural network as a set of Sequential layers is called keras, so we import that too.
#
# 2.   Define and compile the Neural network. It has 1 layers and the layer has 1 neuron, and the input shape to it is just 1 value.
